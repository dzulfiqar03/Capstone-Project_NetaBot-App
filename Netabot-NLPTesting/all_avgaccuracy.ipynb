# %%
import import_ipynb
from netabot_registertest import accuracy_regist as accuracy_registertest
from netabot_logintest import accuracy_login as accuracy_logintest
from netabot_chatbottest import accuracy_chatbot as accuracy_chatbottest
from netabot_producttest import accuracy_product  as accuracy_producttest

# %%
accuracy_scores = [
    accuracy_registertest(),
    accuracy_logintest(),
    accuracy_chatbottest(),
    accuracy_producttest()
]


avg_accuracy = sum(accuracy_scores) / len(accuracy_scores)
print(f"Average Accuracy across all tests: {avg_accuracy:.2f}%")
# Out:
# Average Accuracy across all tests: 0.93%
