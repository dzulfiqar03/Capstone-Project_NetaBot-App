# %%
import pandas as pd
import re
from sklearn.feature_extraction.text import TfidfVectorizer
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LogisticRegression
from sklearn.metrics import (
    accuracy_score,
    classification_report,
    confusion_matrix
)

# %%
df = pd.read_csv("dataset/users.csv")

# %%
def label_login(row):
    email = row["email"].lower()

    if "'" in email:
        return "bot"

    if email.count("@") != 1:
        return "bot"
    if email.count(".") != 1:
        return "bot"
    
    if not email.endswith("@gmail.com"):
        return "bot"
    if not re.match(r"^[a-z0-9@._-]+$", email):
        return "bot"

    return "valid"

df["label"] = df.apply(label_login, axis=1)

# %%
df['email'] = df['email'].str.lower().str.strip()

# %%
df["label"] = df["label"].replace({
    "bot": "invalid"
})

# %%
vectorizer = TfidfVectorizer(
    analyzer='char',
    ngram_range=(2,5),
    max_features=500
)

X = vectorizer.fit_transform(df['email'])
y = df['label']

# %%
X_train, X_test, y_train, y_test = train_test_split(
    X,
    y,
    test_size=0.3,
    random_state=42,
    stratify=y
)

# %%
model = LogisticRegression(max_iter=1000)
model.fit(X_train, y_train)
# Out:
# LogisticRegression(max_iter=1000)

# %%
y_pred = model.predict(X_test)

# %%
accuracy = accuracy_score(y_test, y_pred)

print("===================================")
print(" EMAIL LOGIN NLP CLASSIFICATION ")
print("===================================\n")

print("Accuracy :", round(accuracy, 4), "\n")

print("Classification Report:\n")
print(classification_report(y_test, y_pred))

print("Confusion Matrix:\n")
print(confusion_matrix(y_test, y_pred))
# Out:
# ===================================
#  EMAIL LOGIN NLP CLASSIFICATION
# ===================================
#
# Accuracy : 0.9231
#
# Classification Report:
#
#               precision    recall  f1-score   support
#
#      invalid       0.90      0.96      0.93        46
#        valid       0.95      0.89      0.92        45
#
#     accuracy                           0.92        91
#    macro avg       0.93      0.92      0.92        91
# weighted avg       0.92      0.92      0.92        91
#
# Confusion Matrix:
#
# [[44  2]
#  [ 5 40]]

# %%
import seaborn as sns
import matplotlib.pyplot as plt

sns.heatmap(confusion_matrix(y_test, y_pred), annot=True, fmt="d", cmap="Blues")
plt.xlabel("Predicted")
plt.ylabel("Actual")
plt.title("Confusion Matrix")
plt.show()

# %%
def accuracy_login():
    return round(accuracy_score(y_test, y_pred), 4)
